# %%
x=5
y="5"
print(x+int(y))
# Out:
# 10

# %%
type(3.0)
# Out:
# float

# %%
user_int = int(input("enter your number: "))

# %%
list("hello")
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
list1 = ["orange", "apple", 10]
list1.append("mango")
print(list1)
# Out:
# ['orange', 'apple', 10, 'mango']

# %%
a = [1,2,3]
a[1] = [4, 5]
print(a)
# Out:
# [1, [4, 5], 3]

# %%
list1 = ["orange", "apple", 10, 4, 15, "mango"]
list1.pop()
#list1.remove("mango")
print(list1)
# Out:
# ['orange', 'apple', 10, 4, 15]

# %%
t= (1, 2, 3)
print(t[1])
# Out:
# 2

# %%
s = {1, 2, 3, 2}
print(s)
# Out:
# {1, 2, 3}

# %%
d ={"a":1,"b":2}
print(d.get("c",3))
# Out:
# 3

# %%
x = 5
while x > 0:
    print(x)
    x-=1
# Out:
# 5
# 4
# 3
# 2
# 1
