# %%
# LIST

# 1. Lists are  oredered and enclosed with square bracket,its Mutable.Tuple -- Immutable & Set -- unordered. 
#     List allow duplicates."

# %%
list = [1,2,3,4,5]
print(sum(list))
# Out:
# 15

# %%
# append() -- add one element to the list
# extend() -- add multiple elements

# %%
list1 = [1,1,2,2,3,4,5]
num = list(set(list1))
print(num)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 list1 = [1,1,2,2,3,4,5]
# ----> 2 num = list(set(list1))
#       3 print(num)
#
# TypeError: 'list' object is not callable

# %%
# 5. TUPLE
 # ordered and Immutable collection .its advantages are used for fixed data,memory efficient

# %%
tup = (10,20,30)
a,b,c = tup
print(a,b,c)
# Out:
# 10 20 30

# %%
# No , Tuples cannot be modified because they are immutable

# %%
def max(tup):
    return max_val(tup)

num = (10, 20, 5, 8, 25)
result = max(num)
print("Maximum value =",result)
# Out:
# KeyboardInterrupt

# %%
# DICTIONARIES -- they are key - value pair.Unlike lists are index- based

# %%
# 11. 
for key, value in dict.items():
    print(key , value)
# Out:
# H 1
# e 1
# l 2
# o 1

# %%
keys = ['a', 'b','c']
values = [1,2,3]
d = dict(zip(keys, values))
print(d)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
#Conditional Statement
# used for descision making 
# if -- executes when condition true 
#  elif -- checks multiple condition
#  else -- execute when none is true

# %%
n = 10
print("Even" if n%2 == 0 else "Odd")
# Out:
# Even

# %%
# Pass statement : avoids error

# %%
# Loops

# for -- used when number of iteration is known
# while -- used when iteration depend on a condition

# %%
n= 6
fact = 1
while n > 0:
    fact *= n
    n-= 1
    print(fact)
# Out:
# 6
# 30
# 120
# 360
# 720
# 720

# %%
# 18. Break And Continue
#Break -- exits loop
#Continue -- skips to next iteration

for i in range (4):
    if i == 3 : break
    if i == 2 : continue
    print(i)
# Out:
# 0
# 1

# %%
#19.
 
for n in range(2, 101):
    prime = True
    for i in range (2, n):
        if n % i == 0:
            prime = False
            break
    if prime :
       print (n, ends= " ")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 10
#       8         break
#       9 if prime :
# ---> 10    print (n, ends= " ")
#
# TypeError: 'ends' is an invalid keyword argument for print()

# %%
# Python standared Libraries -- built-in modules.They save time and effort

# %%
import math
r = 5
print(math.pi * r**2)
# Out:
# 78.53981633974483

# %%
# datetime -- used for date/time manipulation

# %%
from datetime import datetime
print(datetime.now())
# Out:
# 2025-10-03 10:23:24.958540

# %%
# lambda -- anonymous function .shorten and one-time use

# %%
num =[1,2,3]
sq = list(map(lambda x: x**2,num))
print(sq)
# Out:
# [1, 4, 9]
